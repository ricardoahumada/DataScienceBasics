# %% [markdown]
# # Academic Analyzer Client

# %%
from academic_analyzer import AcademicPerformanceAnalyzer

# Opción 1: datos aleatorios reproducibles
analizador = AcademicPerformanceAnalyzer(seed=42)
analizador.resumen()

# Opción 2: datos personalizados
datos_propios = [
    [8.5, 7.0, np.nan, 9.0],
    [3.0, 4.5, 5.0, 2.0],
    [np.nan, np.nan, 6.0, 7.5]
]
analizador2 = AcademicPerformanceAnalyzer(notas=datos_propios)
print("\nPromedios por estudiante:", analizador2.promedio_por_estudiante)
