# %% [markdown]
# ## Sales

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# %%
sales_df = pd.read_csv('https://github.com/ricardoahumada/DataScienceBasics/raw/refs/heads/main/data/company_sales/sales.csv')

# %%
# Columnas
sales_df.columns = ['orderNumber', 'orderLineNumber', 'orderDate', 'shippedDate', 'requiredDate', 'customerNumber',
                    'employeeNumber', 'productCode', 'status', 'comments', 'quantityOrdered', 'priceEach', 'sales_amount', 'origin']
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3001 entries, 0 to 3000
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   orderNumber      3001 non-null   int64
#  1   orderLineNumber  3001 non-null   int64
#  2   orderDate        3001 non-null   object
#  3   shippedDate      2859 non-null   object
#  4   requiredDate     3001 non-null   object
#  5   customerNumber   3001 non-null   int64
#  6   employeeNumber   3001 non-null   int64
#  7   productCode      3001 non-null   object
#  8   status           3001 non-null   object
#  9   comments         759 non-null    object
#  10  quantityOrdered  3001 non-null   int64
#  11  priceEach        3001 non-null   float64
#  12  sales_amount     3001 non-null   float64
#  13  origin           3001 non-null   object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 328.4+ KB

# %% [markdown]
# - Barras
# - Scatter
# - Histogramas
# - Cajas

# %%
import matplotlib.pyplot as plt

# %%
status_cats = sales_df.groupby('status').agg(num=('status', 'count'))
print(status_cats)

fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(status_cats.index, status_cats['num'], color='blue', label='num')
ax.legend(loc='upper left')
ax.set_title('Conteo de status')
# Out:
#              num
# status
# Cancelled     79
# Disputed      14
# In Process    42
# On Hold       44
# Resolved      47
# Shipped     2775
# Text(0.5, 1.0, 'Conteo de status')

# %%
status_cats.plot(y='num', kind='pie', legend=False)
# Out:
# <AxesSubplot: ylabel='num'>

# %%
# scatter
variables = ['quantityOrdered', 'priceEach', 'sales_amount']

fig = plt.figure(figsize = (14, 8))

for i in range(0,3):
    fig.add_subplot(3, 1, i+1)
    ax = plt.scatter(sales_df[variables[i]], sales_df[variables[2]], label=variables[i])
    # plt.xlim(0.0, 100.0)
    plt.legend()
    
    
plt.show()

# %%
# histogramas
quantityOrdered = sales_df['quantityOrdered']

fig, ax = plt.subplots(figsize=(10, 4))
ax.hist(quantityOrdered, np.arange(0, 101))

# ax.set_ylabel('Freq')
ax.set_title('Histograma')
# Out:
# Text(0.5, 1.0, 'Histograma')

# %%
sales_df['quantityOrdered'].hist(bins=100)
# Out:
# <AxesSubplot: >

# %%
sales_df[sales_df['quantityOrdered'] >= 0].hist(bins=100, figsize=(20,25))
# plt.rcParams["figure.figsize"] = [20, 25]
plt.show()

# %%
# boxplot
sales_df.boxplot(return_type='axes',figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
sales_df[['priceEach']].boxplot(return_type='axes',figsize=(10,5))
# Out:
# <AxesSubplot: >

# %%
# heatmaps
sales_corr = sales_df.corr('pearson')
sales_corr.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a33b0_row0_col0, #T_a33b0_row1_col1, #T_a33b0_row2_col2, #T_a33b0_row3_col3, #T_a33b0_row4_col4, #T_a33b0_row5_col5, #T_a33b0_row6_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a33b0_row0_col1, #T_a33b0_row1_col0, #T_a33b0_row1_col2, #T_a33b0_row1_col4, #T_a33b0_row1_col6, #T_a33b0_row2_col5, #T_a33b0_row3_col4, #T_a33b0_row4_col3, #T_a33b0_row6_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a33b0_row0_col2, #T_a33b0_row2_col4 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_a33b0_row0_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_a33b0_row0_col4 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_a33b0_row0_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_a33b0_row0_col6 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_a33b0_row1_col3, #T_a33b0_row1_col5 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_a33b0_row2_col0, #T_a33b0_row5_col0, #T_a33b0_row5_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_a33b0_row2_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_a33b0_row2_col3 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_a33b0_row2_col6 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_a33b0_row3_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_a33b0_row3_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_a33b0_row3_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_a33b0_row3_col5 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_a33b0_row3_col6, #T_a33b0_row5_col2, #T_a33b0_row5_col3, #T_a33b0_row6_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_a33b0_row4_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_a33b0_row4_col1, #T_a33b0_row5_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_a33b0_row4_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_a33b0_row4_col5 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_a33b0_row4_col6 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_a33b0_row5_col6, #T_a33b0_row6_col5 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_a33b0_row6_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_a33b0_row6_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_a33b0_row6_col4 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a33b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >orderNumber</th>
#       <th class="col_heading level0 col1" >orderLineNumber</th>
#       <th class="col_heading level0 col2" >customerNumber</th>
#       <th class="col_heading level0 col3" >employeeNumber</th>
#       <th class="col_heading level0 col4" >quantityOrdered</th>
#       <th class="col_heading level0 col5" >priceEach</th>
#       <th class="col_heading level0 col6" >sales_amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a33b0_level0_row0" class="row_heading level0 row0" >orderNumber</th>
#       <td id="T_a33b0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a33b0_row0_col1" class="data row0 col1" >-0.050853</td>
#       <td id="T_a33b0_row0_col2" class="data row0 col2" >-0.000871</td>
#       <td id="T_a33b0_row0_col3" class="data row0 col3" >0.112239</td>
#       <td id="T_a33b0_row0_col4" class="data row0 col4" >0.077880</td>
#       <td id="T_a33b0_row0_col5" class="data row0 col5" >-0.003917</td>
#       <td id="T_a33b0_row0_col6" class="data row0 col6" >0.041960</td>
#     </tr>
#     <tr>
#       <th id="T_a33b0_level0_row1" class="row_heading level0 row1" >orderLineNumber</th>
#       <td id="T_a33b0_row1_col0" class="data row1 col0" >-0.050853</td>
#       <td id="T_a33b0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a33b0_row1_col2" class="data row1 col2" >-0.043279</td>
#       <td id="T_a33b0_row1_col3" class="data row1 col3" >-0.012187</td>
#       <td id="T_a33b0_row1_col4" class="data row1 col4" >-0.020396</td>
#       <td id="T_a33b0_row1_col5" class="data row1 col5" >-0.018829</td>
#       <td id="T_a33b0_row1_col6" class="data row1 col6" >-0.034630</td>
#     </tr>
#     <tr>
#       <th id="T_a33b0_level0_row2" class="row_heading level0 row2" >customerNumber</th>
#       <td id="T_a33b0_row2_col0" class="data row2 col0" >-0.000871</td>
#       <td id="T_a33b0_row2_col1" class="data row2 col1" >-0.043279</td>
#       <td id="T_a33b0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a33b0_row2_col3" class="data row2 col3" >0.069613</td>
#       <td id="T_a33b0_row2_col4" class="data row2 col4" >0.019246</td>
#       <td id="T_a33b0_row2_col5" class="data row2 col5" >-0.027937</td>
#       <td id="T_a33b0_row2_col6" class="data row2 col6" >-0.008249</td>
#     </tr>
#     <tr>
#       <th id="T_a33b0_level0_row3" class="row_heading level0 row3" >employeeNumber</th>
#       <td id="T_a33b0_row3_col0" class="data row3 col0" >0.112239</td>
#       <td id="T_a33b0_row3_col1" class="data row3 col1" >-0.012187</td>
#       <td id="T_a33b0_row3_col2" class="data row3 col2" >0.069613</td>
#       <td id="T_a33b0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a33b0_row3_col4" class="data row3 col4" >-0.023855</td>
#       <td id="T_a33b0_row3_col5" class="data row3 col5" >-0.009872</td>
#       <td id="T_a33b0_row3_col6" class="data row3 col6" >-0.021265</td>
#     </tr>
#     <tr>
#       <th id="T_a33b0_level0_row4" class="row_heading level0 row4" >quantityOrdered</th>
#       <td id="T_a33b0_row4_col0" class="data row4 col0" >0.077880</td>
#       <td id="T_a33b0_row4_col1" class="data row4 col1" >-0.020396</td>
#       <td id="T_a33b0_row4_col2" class="data row4 col2" >0.019246</td>
#       <td id="T_a33b0_row4_col3" class="data row4 col3" >-0.023855</td>
#       <td id="T_a33b0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a33b0_row4_col5" class="data row4 col5" >0.024733</td>
#       <td id="T_a33b0_row4_col6" class="data row4 col6" >0.575010</td>
#     </tr>
#     <tr>
#       <th id="T_a33b0_level0_row5" class="row_heading level0 row5" >priceEach</th>
#       <td id="T_a33b0_row5_col0" class="data row5 col0" >-0.003917</td>
#       <td id="T_a33b0_row5_col1" class="data row5 col1" >-0.018829</td>
#       <td id="T_a33b0_row5_col2" class="data row5 col2" >-0.027937</td>
#       <td id="T_a33b0_row5_col3" class="data row5 col3" >-0.009872</td>
#       <td id="T_a33b0_row5_col4" class="data row5 col4" >0.024733</td>
#       <td id="T_a33b0_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_a33b0_row5_col6" class="data row5 col6" >0.803276</td>
#     </tr>
#     <tr>
#       <th id="T_a33b0_level0_row6" class="row_heading level0 row6" >sales_amount</th>
#       <td id="T_a33b0_row6_col0" class="data row6 col0" >0.041960</td>
#       <td id="T_a33b0_row6_col1" class="data row6 col1" >-0.034630</td>
#       <td id="T_a33b0_row6_col2" class="data row6 col2" >-0.008249</td>
#       <td id="T_a33b0_row6_col3" class="data row6 col3" >-0.021265</td>
#       <td id="T_a33b0_row6_col4" class="data row6 col4" >0.575010</td>
#       <td id="T_a33b0_row6_col5" class="data row6 col5" >0.803276</td>
#       <td id="T_a33b0_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(14, 10))
shw = ax.imshow(sales_corr, cmap='jet', aspect='auto')
bar = plt.colorbar(shw) 

# https://matplotlib.org/stable/users/explain/colors/colormaps.html
ax.set_yticks(np.arange(0, len(sales_corr.index), 1), sales_corr.index)
ax.set_xticks(np.arange(0, len(sales_corr.columns), 1), sales_corr.columns)

plt.show()
